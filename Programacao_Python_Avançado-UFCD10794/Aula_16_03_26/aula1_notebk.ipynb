# %%
nome1 = 'ca'
nome2 = 'alberto'

print(nome1 > nome2)
# Out:
# True

# %% [markdown]
# Truthy e Falsy

# %%
#Valores Falsy
lista_vazia = []
velocidade_inicial = 0
Flag_ativa = False
tuplo_vazio = ()

if lista_vazia: print(bool(lista_vazia))
else: print("Falsy value")
# Out:
# Falsy value

# %%
#Valores Falsy
lista_vazia = [1]
velocidade_inicial = 0
Flag_ativa = False
tuplo_vazio = ()

if lista_vazia: print(bool(lista_vazia))
else: print("Falsy value")
# Out:
# True

# %%
#Valores Falsy
lista_vazia = [1]
velocidade_inicial = 0
Flag_ativa = False
tuplo_vazio = ()

if False: print(bool(lista_vazia))
else: print("Falsy value")
# Out:
# Falsy value

# %%
#Valores Falsy
lista_vazia = [1]
velocidade_inicial = 0
Flag_ativa = False
tuplo_vazio = ()

if True: print(bool(lista_vazia))
else: print("Falsy value")
# Out:
# True

# %%
x=7
if x%2 == 0: print("nr par")
else: print("nr impar")
# Out:
# nr impar

# %%
frutas = ["maca", "banana", "laranja", "papaia"]
if"banana" in frutas:
    print("sim")
# Out:
# sim

# %%
semana=['Segunda', 'Terca', 'Quarta', 'Quinta']
if 'Domingo' not in semana:
    print('Não há Domingo na lista semanal')
# Out:
# Não há Domingo na lista semanal

# %% [markdown]
# Operadores IN e NOT IN

# %%
dicionario= (1: "one", 2:"two", 3:"three", 4:"four")
if "one" in dicionario: print("encontrei")
# Out:
# encontrei

# %%
def soma(x,y):
    return
print (soma(4,5))
# Out:
# None

# %%
def dizer_ola():
    return

print (dizer_ola)
# Out:
# <function dizer_ola at 0x00000148681D4510>

# %%
quantidade=10
nr_item=567
preco=49.99
encomenda= "Encomendou {} quantidade de artigo nr. {} por {} $."
print(encomenda.format(quantidade,nr_item,preco))
# Out:
# Encomendou 10 quantidade de artigo nr. 567 por 49.99 $.
