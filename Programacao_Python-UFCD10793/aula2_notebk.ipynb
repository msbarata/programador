# %% [markdown]
# ### Função print

# %%
print("Maria")
# Out:
# Maria

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Demontrated")
# Out:
# Demontrated

# %% [markdown]
# ## Tudo sobre listas

# %%
lista =[1,2,3,4,5]
print(lista)
# Out:
# [1, 2, 3, 4, 5]

# %%
print("teste")
# Out:
# teste
